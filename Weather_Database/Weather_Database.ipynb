# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lats_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 796

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description=city_weather["weather"][0]["description"]      
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                            "Country": city_country,
                            "Lat": city_lat,
                            "Lng": city_lng,
                            "Max Temp": city_max_temp,
                            "Humidity": city_humidity,
                            "Cloudiness": city_clouds,
                            "Wind Speed": city_wind,                                                         
                            "Current Description":city_weather_description,
                          })
                                  
    # If an error is experienced, skip the city
    except: 
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | olafsvik
# Processing Record 2 of Set 1 | bluff
# Processing Record 3 of Set 1 | husavik
# Processing Record 4 of Set 1 | bambous virieux
# Processing Record 5 of Set 1 | tiksi
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | khatanga
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | atuona
# Processing Record 10 of Set 1 | mehamn
# Processing Record 11 of Set 1 | vaini
# Processing Record 12 of Set 1 | ballina
# Processing Record 13 of Set 1 | arraial do cabo
# Processing Record 14 of Set 1 | new norfolk
# Processing Record 15 of Set 1 | seydi
# Processing Record 16 of Set 1 | puerto ayora
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | hobart
# Processing Record 19 of Set 1 | mataura
# Processing Record 20 of Set 1 | camacha
# Processing Record 21 of Set 1 | jamestown
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | staraya toropa
# Processing Record 24 of Set 1 | mushie
# Processing Record 25 of Set 1 | srednekolymsk
# Processing Record 26 of Set 1 | dunedin
# Processing Record 27 of Set 1 | baringo
# Processing Record 28 of Set 1 | thompson
# Processing Record 29 of Set 1 | champasak
# Processing Record 30 of Set 1 | pacific grove
# Processing Record 31 of Set 1 | kaniama
# Processing Record 32 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 1 | kavaratti
# Processing Record 34 of Set 1 | ossora
# Processing Record 35 of Set 1 | mar del plata
# Processing Record 36 of Set 1 | tasiilaq
# Processing Record 37 of Set 1 | hami
# Processing Record 38 of Set 1 | hithadhoo
# Processing Record 39 of Set 1 | port elizabeth
# Processing Record 40 of Set 1 | geraldton
# Processing Record 41 of Set 1 | nebbi
# Processing Record 42 of Set 1 | sorland
# Processing Record 43 of Set 1 | avarua
# Processing Record 44 of Set 1 | vilhena
# Processing Record 45 of Set 1 | punta arenas
# Processing Record 46 of Set 1 | ailigandi
# Processing Record 47 of Set 1 | rocha
# Processing Record 48 of Set 1 | la ronge
# Processing Record 49 of Set 1 | bethel
# Processing Record 50 of Set 1 | ponta do sol
# Processing Record 1 of Set 2 | hilo
# Processing Record 2 of Set 2 | georgetown
# Processing Record 3 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 4 of Set 2 | kodiak
# Processing Record 5 of Set 2 | nikolskoye
# Processing Record 6 of Set 2 | kulhudhuffushi
# Processing Record 7 of Set 2 | ola
# Processing Record 8 of Set 2 | cabo san lucas
# Processing Record 9 of Set 2 | ous
# Processing Record 10 of Set 2 | kapaa
# Processing Record 11 of Set 2 | skjervoy
# Processing Record 12 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 2 | dikson
# Processing Record 14 of Set 2 | primorsko
# Processing Record 15 of Set 2 | tabou
# Processing Record 16 of Set 2 | anadyr
# Processing Record 17 of Set 2 | yellowknife
# Processing Record 18 of Set 2 | praya
# Processing Record 19 of Set 2 | saskylakh
# Processing Record 20 of Set 2 | butaritari
# Processing Record 21 of Set 2 | saint-augustin
# Processing Record 22 of Set 2 | arrecife
# Processing Record 23 of Set 2 | jurmala
# Processing Record 24 of Set 2 | nanortalik
# Processing Record 25 of Set 2 | xacmaz
# Processing Record 26 of Set 2 | lebu
# Processing Record 27 of Set 2 | christchurch
# Processing Record 28 of Set 2 | vestmannaeyjar
# Processing Record 29 of Set 2 | melfort
# Processing Record 30 of Set 2 | bredasdorp
# Processing Record 31 of Set 2 | jumla
# Processing Record 32 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 2 | saint-philippe
# Processing Record 34 of Set 2 | esperance
# Processing Record 35 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 2 | machinga
# Processing Record 37 of Set 2 | sarangani
# Processing Record 38 of Set 2 | magdagachi
# Processing Record 39 of Set 2 | cape town
# Processing Record 40 of Set 2 | huilong
# Processing Record 41 of Set 2 | millau
# Processing Record 42 of Set 2 | phan thiet
# Processing Record 43 of Set 2 | inuvik
# Processing Record 44 of Set 2 | balaipungut
# Processing Record 45 of Set 2 | governador dix-sept rosado
# Processing Record 46 of Set 2 | faya
# Processing Record 47 of Set 2 | salinopolis
# Processing Record 48 of Set 2 | camp verde
# Processing Record 49 of Set 2 | anar darreh
# City not found. Skipping...
# Processing Record 50 of Set 2 | oussouye
# Processing Record 1 of Set 3 | torbay
# Processing Record 2 of Set 3 | poum
# Processing Record 3 of Set 3 | bauchi
# Processing Record 4 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 5 of Set 3 | tortoli
# Processing Record 6 of Set 3 | nishihara
# Processing Record 7 of Set 3 | portland
# Processing Record 8 of Set 3 | rovaniemi
# Processing Record 9 of Set 3 | barrow
# Processing Record 10 of Set 3 | ahipara
# Processing Record 11 of Set 3 | luderitz
# Processing Record 12 of Set 3 | sakakah
# Processing Record 13 of Set 3 | brewster
# Processing Record 14 of Set 3 | aykhal
# Processing Record 15 of Set 3 | berezniki
# Processing Record 16 of Set 3 | haibowan
# City not found. Skipping...
# Processing Record 17 of Set 3 | klaksvik
# Processing Record 18 of Set 3 | tautira
# Processing Record 19 of Set 3 | namibe
# Processing Record 20 of Set 3 | los llanos de aridane
# Processing Record 21 of Set 3 | busayra
# Processing Record 22 of Set 3 | ilulissat
# Processing Record 23 of Set 3 | zyryanka
# Processing Record 24 of Set 3 | roma
# Processing Record 25 of Set 3 | lincoln
# Processing Record 26 of Set 3 | phan rang
# City not found. Skipping...
# Processing Record 27 of Set 3 | adrasmon
# Processing Record 28 of Set 3 | san cristobal
# Processing Record 29 of Set 3 | emerald
# Processing Record 30 of Set 3 | airai
# Processing Record 31 of Set 3 | katsuura
# Processing Record 32 of Set 3 | minab
# Processing Record 33 of Set 3 | hermanus
# Processing Record 34 of Set 3 | robertsport
# Processing Record 35 of Set 3 | price
# Processing Record 36 of Set 3 | kaitangata
# Processing Record 37 of Set 3 | kangaatsiaq
# Processing Record 38 of Set 3 | evensk
# Processing Record 39 of Set 3 | minnedosa
# Processing Record 40 of Set 3 | chuy
# Processing Record 41 of Set 3 | mangrol
# Processing Record 42 of Set 3 | tianpeng
# Processing Record 43 of Set 3 | mana
# Processing Record 44 of Set 3 | tual
# Processing Record 45 of Set 3 | mbaiki
# Processing Record 46 of Set 3 | adzope
# Processing Record 47 of Set 3 | provideniya
# Processing Record 48 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 3 | alihe
# Processing Record 50 of Set 3 | adwa
# Processing Record 1 of Set 4 | comodoro rivadavia
# Processing Record 2 of Set 4 | bukachacha
# Processing Record 3 of Set 4 | trujillo
# Processing Record 4 of Set 4 | castro
# Processing Record 5 of Set 4 | chokurdakh
# Processing Record 6 of Set 4 | lavrentiya
# Processing Record 7 of Set 4 | dombarovskiy
# Processing Record 8 of Set 4 | cidreira
# Processing Record 9 of Set 4 | kununurra
# Processing Record 10 of Set 4 | afmadu
# City not found. Skipping...
# Processing Record 11 of Set 4 | bilma
# Processing Record 12 of Set 4 | talnakh
# Processing Record 13 of Set 4 | kurovskoye
# Processing Record 14 of Set 4 | kuldur
# Processing Record 15 of Set 4 | nelson bay
# Processing Record 16 of Set 4 | pobe
# Processing Record 17 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 4 | half moon bay
# Processing Record 19 of Set 4 | bulgan
# Processing Record 20 of Set 4 | korla
# Processing Record 21 of Set 4 | faanui
# Processing Record 22 of Set 4 | don benito
# Processing Record 23 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 4 | presidencia roque saenz pena
# Processing Record 25 of Set 4 | ambulu
# Processing Record 26 of Set 4 | salekhard
# Processing Record 27 of Set 4 | grindavik
# Processing Record 28 of Set 4 | anchorage
# Processing Record 29 of Set 4 | grand gaube
# Processing Record 30 of Set 4 | bairiki
# Processing Record 31 of Set 4 | bathurst
# Processing Record 32 of Set 4 | ishikari
# Processing Record 33 of Set 4 | ust-tsilma
# Processing Record 34 of Set 4 | mogzon
# Processing Record 35 of Set 4 | pevek
# Processing Record 36 of Set 4 | santiago del estero
# Processing Record 37 of Set 4 | east london
# Processing Record 38 of Set 4 | tomatlan
# Processing Record 39 of Set 4 | na klang
# Processing Record 40 of Set 4 | fez
# Processing Record 41 of Set 4 | qaanaaq
# Processing Record 42 of Set 4 | hauterive
# Processing Record 43 of Set 4 | kismayo
# Processing Record 44 of Set 4 | mackay
# Processing Record 45 of Set 4 | bonavista
# Processing Record 46 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 4 | guna
# Processing Record 48 of Set 4 | izacic
# Processing Record 49 of Set 4 | berbera
# Processing Record 50 of Set 4 | malwan
# City not found. Skipping...
# Processing Record 1 of Set 5 | hakodate
# Processing Record 2 of Set 5 | coronado
# Processing Record 3 of Set 5 | teseney
# Processing Record 4 of Set 5 | karratha
# Processing Record 5 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 5 | pilas
# Processing Record 7 of Set 5 | taitung
# Processing Record 8 of Set 5 | leningradskiy
# Processing Record 9 of Set 5 | richards bay
# Processing Record 10 of Set 5 | rolim de moura
# City not found. Skipping...
# Processing Record 11 of Set 5 | mokrousovo
# Processing Record 12 of Set 5 | beringovskiy
# Processing Record 13 of Set 5 | villarrica
# Processing Record 14 of Set 5 | annau
# Processing Record 15 of Set 5 | longyearbyen
# Processing Record 16 of Set 5 | tuktoyaktuk
# Processing Record 17 of Set 5 | progreso
# Processing Record 18 of Set 5 | boca do acre
# Processing Record 19 of Set 5 | lagoa
# Processing Record 20 of Set 5 | lloydminster
# Processing Record 21 of Set 5 | jeronimo monteiro
# Processing Record 22 of Set 5 | hofn
# Processing Record 23 of Set 5 | bathsheba
# Processing Record 24 of Set 5 | saint anthony
# Processing Record 25 of Set 5 | upernavik
# Processing Record 26 of Set 5 | iisalmi
# Processing Record 27 of Set 5 | oga
# Processing Record 28 of Set 5 | forio
# Processing Record 29 of Set 5 | ladwa
# Processing Record 30 of Set 5 | guelavia
# City not found. Skipping...
# Processing Record 31 of Set 5 | navolato
# Processing Record 32 of Set 5 | beloha
# Processing Record 33 of Set 5 | ribeira grande
# Processing Record 34 of Set 5 | mazara del vallo
# Processing Record 35 of Set 5 | ostrovnoy
# Processing Record 36 of Set 5 | grimari
# City not found. Skipping...
# Processing Record 37 of Set 5 | khani
# Processing Record 38 of Set 5 | san patricio
# Processing Record 39 of Set 5 | custoias
# Processing Record 40 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 5 | kavieng
# Processing Record 42 of Set 5 | chernyshevskiy
# Processing Record 43 of Set 5 | alta floresta
# Processing Record 44 of Set 5 | laguna
# Processing Record 45 of Set 5 | urumqi
# Processing Record 46 of Set 5 | insar
# Processing Record 47 of Set 5 | thinadhoo
# Processing Record 48 of Set 5 | port alfred
# Processing Record 49 of Set 5 | beian
# Processing Record 50 of Set 5 | bengkulu
# Processing Record 1 of Set 6 | priiskovyy
# Processing Record 2 of Set 6 | norman wells
# Processing Record 3 of Set 6 | karauzyak
# City not found. Skipping...
# Processing Record 4 of Set 6 | paita
# Processing Record 5 of Set 6 | khash
# Processing Record 6 of Set 6 | lagos
# Processing Record 7 of Set 6 | benguela
# Processing Record 8 of Set 6 | portobelo
# Processing Record 9 of Set 6 | kisesa
# Processing Record 10 of Set 6 | pangnirtung
# Processing Record 11 of Set 6 | kamaishi
# Processing Record 12 of Set 6 | la palma
# Processing Record 13 of Set 6 | shenjiamen
# Processing Record 14 of Set 6 | nyurba
# Processing Record 15 of Set 6 | chiang khong
# Processing Record 16 of Set 6 | chicama
# Processing Record 17 of Set 6 | ishigaki
# Processing Record 18 of Set 6 | trelew
# Processing Record 19 of Set 6 | soyo
# Processing Record 20 of Set 6 | camocim
# Processing Record 21 of Set 6 | rio grande
# Processing Record 22 of Set 6 | neral
# Processing Record 23 of Set 6 | shimoda
# Processing Record 24 of Set 6 | fare
# Processing Record 25 of Set 6 | lompoc
# Processing Record 26 of Set 6 | botad
# Processing Record 27 of Set 6 | pangai
# Processing Record 28 of Set 6 | lerwick
# Processing Record 29 of Set 6 | kahului
# Processing Record 30 of Set 6 | whitley bay
# Processing Record 31 of Set 6 | canutama
# Processing Record 32 of Set 6 | hanstholm
# Processing Record 33 of Set 6 | alice springs
# Processing Record 34 of Set 6 | pechora
# Processing Record 35 of Set 6 | margate
# Processing Record 36 of Set 6 | nioki
# Processing Record 37 of Set 6 | fortuna
# Processing Record 38 of Set 6 | pangody
# Processing Record 39 of Set 6 | zhifang
# Processing Record 40 of Set 6 | marystown
# Processing Record 41 of Set 6 | severo-kurilsk
# Processing Record 42 of Set 6 | dingle
# Processing Record 43 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 44 of Set 6 | fomboni
# Processing Record 45 of Set 6 | san isidro
# Processing Record 46 of Set 6 | santa cruz
# Processing Record 47 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 48 of Set 6 | male
# Processing Record 49 of Set 6 | biloela
# Processing Record 50 of Set 6 | bida
# Processing Record 1 of Set 7 | cam ranh
# Processing Record 2 of Set 7 | te anau
# Processing Record 3 of Set 7 | cherskiy
# Processing Record 4 of Set 7 | maniitsoq
# Processing Record 5 of Set 7 | kyren
# Processing Record 6 of Set 7 | cercal
# Processing Record 7 of Set 7 | yeppoon
# Processing Record 8 of Set 7 | cayenne
# Processing Record 9 of Set 7 | leiva
# Processing Record 10 of Set 7 | elizabeth city
# Processing Record 11 of Set 7 | paka
# Processing Record 12 of Set 7 | tromso
# Processing Record 13 of Set 7 | port-cartier
# Processing Record 14 of Set 7 | sola
# Processing Record 15 of Set 7 | sinop
# Processing Record 16 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 17 of Set 7 | lisakovsk
# Processing Record 18 of Set 7 | mananjary
# Processing Record 19 of Set 7 | touros
# Processing Record 20 of Set 7 | rosetown
# Processing Record 21 of Set 7 | ancud
# Processing Record 22 of Set 7 | mahanje
# Processing Record 23 of Set 7 | constitucion
# Processing Record 24 of Set 7 | san rafael del sur
# Processing Record 25 of Set 7 | clyde river
# Processing Record 26 of Set 7 | chapais
# Processing Record 27 of Set 7 | tessalit
# Processing Record 28 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 29 of Set 7 | atambua
# Processing Record 30 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 31 of Set 7 | opuwo
# Processing Record 32 of Set 7 | purmerend
# Processing Record 33 of Set 7 | mogadishu
# Processing Record 34 of Set 7 | carnarvon
# Processing Record 35 of Set 7 | itoman
# Processing Record 36 of Set 7 | bangalore
# Processing Record 37 of Set 7 | malakal
# Processing Record 38 of Set 7 | turukhansk
# Processing Record 39 of Set 7 | tura
# Processing Record 40 of Set 7 | meulaboh
# Processing Record 41 of Set 7 | muravlenko
# Processing Record 42 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 7 | mayumba
# Processing Record 44 of Set 7 | labrea
# Processing Record 45 of Set 7 | adrar
# Processing Record 46 of Set 7 | trat
# Processing Record 47 of Set 7 | langham
# Processing Record 48 of Set 7 | moerai
# Processing Record 49 of Set 7 | walvis bay
# Processing Record 50 of Set 7 | marinette
# Processing Record 1 of Set 8 | aswan
# Processing Record 2 of Set 8 | vao
# Processing Record 3 of Set 8 | nola
# Processing Record 4 of Set 8 | brae
# Processing Record 5 of Set 8 | ciudad bolivar
# Processing Record 6 of Set 8 | tsalka
# Processing Record 7 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 8 of Set 8 | kichera
# Processing Record 9 of Set 8 | mbandaka
# Processing Record 10 of Set 8 | cairns
# Processing Record 11 of Set 8 | kudahuvadhoo
# Processing Record 12 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 8 | wisconsin rapids
# Processing Record 14 of Set 8 | college
# Processing Record 15 of Set 8 | labuhan
# Processing Record 16 of Set 8 | asau
# Processing Record 17 of Set 8 | inhambane
# Processing Record 18 of Set 8 | yuzhnyy
# Processing Record 19 of Set 8 | omsukchan
# Processing Record 20 of Set 8 | zavidovici
# Processing Record 21 of Set 8 | kensington
# Processing Record 22 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 8 | san quintin
# Processing Record 24 of Set 8 | leh
# Processing Record 25 of Set 8 | kandiaro
# Processing Record 26 of Set 8 | sao filipe
# Processing Record 27 of Set 8 | cockburn harbour
# City not found. Skipping...
# Processing Record 28 of Set 8 | kuybysheve
# Processing Record 29 of Set 8 | quatre cocos
# Processing Record 30 of Set 8 | port lincoln
# Processing Record 31 of Set 8 | manta
# Processing Record 32 of Set 8 | kudat
# Processing Record 33 of Set 8 | hadejia
# Processing Record 34 of Set 8 | la rioja
# Processing Record 35 of Set 8 | maroantsetra
# Processing Record 36 of Set 8 | port blair
# Processing Record 37 of Set 8 | denpasar
# Processing Record 38 of Set 8 | bihoro
# Processing Record 39 of Set 8 | sept-iles
# Processing Record 40 of Set 8 | albert lea
# Processing Record 41 of Set 8 | ezhou
# Processing Record 42 of Set 8 | banda aceh
# Processing Record 43 of Set 8 | mahibadhoo
# Processing Record 44 of Set 8 | bulalacao
# Processing Record 45 of Set 8 | sangar
# Processing Record 46 of Set 8 | najran
# Processing Record 47 of Set 8 | leiyang
# Processing Record 48 of Set 8 | sao joao da barra
# Processing Record 49 of Set 8 | belaya gora
# Processing Record 50 of Set 8 | xiuyan
# Processing Record 1 of Set 9 | riyadh
# Processing Record 2 of Set 9 | mount gambier
# Processing Record 3 of Set 9 | cheuskiny
# City not found. Skipping...
# Processing Record 4 of Set 9 | yatou
# Processing Record 5 of Set 9 | ouadda
# Processing Record 6 of Set 9 | ginda
# Processing Record 7 of Set 9 | serebryansk
# Processing Record 8 of Set 9 | maturin
# Processing Record 9 of Set 9 | werda
# Processing Record 10 of Set 9 | sinnamary
# Processing Record 11 of Set 9 | lujan
# Processing Record 12 of Set 9 | coihaique
# Processing Record 13 of Set 9 | warri
# Processing Record 14 of Set 9 | muros
# Processing Record 15 of Set 9 | tuban
# Processing Record 16 of Set 9 | prabumulih
# Processing Record 17 of Set 9 | angoche
# Processing Record 18 of Set 9 | nemuro
# Processing Record 19 of Set 9 | verkhoyansk
# Processing Record 20 of Set 9 | porto novo
# Processing Record 21 of Set 9 | yining
# Processing Record 22 of Set 9 | vung tau
# Processing Record 23 of Set 9 | iacobeni
# Processing Record 24 of Set 9 | urucara
# Processing Record 25 of Set 9 | waingapu
# Processing Record 26 of Set 9 | yangjiang
# Processing Record 27 of Set 9 | basco
# Processing Record 28 of Set 9 | mandalgovi
# Processing Record 29 of Set 9 | eureka
# Processing Record 30 of Set 9 | san buenaventura
# Processing Record 31 of Set 9 | victoria
# Processing Record 32 of Set 9 | amilly
# Processing Record 33 of Set 9 | tawang
# Processing Record 34 of Set 9 | avera
# Processing Record 35 of Set 9 | umm ruwabah
# City not found. Skipping...
# Processing Record 36 of Set 9 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 37 of Set 9 | salalah
# Processing Record 38 of Set 9 | galiwinku
# City not found. Skipping...
# Processing Record 39 of Set 9 | nioro
# Processing Record 40 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 41 of Set 9 | heinola
# Processing Record 42 of Set 9 | muli
# Processing Record 43 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 44 of Set 9 | bicaz
# Processing Record 45 of Set 9 | marawi
# Processing Record 46 of Set 9 | vilcun
# Processing Record 47 of Set 9 | biltine
# Processing Record 48 of Set 9 | nome
# Processing Record 49 of Set 9 | fairbanks
# Processing Record 50 of Set 9 | helong
# Processing Record 1 of Set 10 | koppies
# Processing Record 2 of Set 10 | prado
# Processing Record 3 of Set 10 | sao sebastiao
# Processing Record 4 of Set 10 | tongzi
# Processing Record 5 of Set 10 | bell ville
# Processing Record 6 of Set 10 | mecca
# Processing Record 7 of Set 10 | malinta
# Processing Record 8 of Set 10 | arak
# Processing Record 9 of Set 10 | mareeba
# Processing Record 10 of Set 10 | pumiao
# Processing Record 11 of Set 10 | yenagoa
# Processing Record 12 of Set 10 | ayan
# Processing Record 13 of Set 10 | batagay-alyta
# Processing Record 14 of Set 10 | kobojango
# City not found. Skipping...
# Processing Record 15 of Set 10 | yulara
# Processing Record 16 of Set 10 | yerbogachen
# Processing Record 17 of Set 10 | egvekinot
# Processing Record 18 of Set 10 | souillac
# Processing Record 19 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 20 of Set 10 | salina
# Processing Record 21 of Set 10 | pombas
# Processing Record 22 of Set 10 | zholymbet
# Processing Record 23 of Set 10 | alofi
# Processing Record 24 of Set 10 | berlevag
# Processing Record 25 of Set 10 | presidente epitacio
# Processing Record 26 of Set 10 | linhares
# Processing Record 27 of Set 10 | colac
# Processing Record 28 of Set 10 | nanakuli
# Processing Record 29 of Set 10 | pakxan
# Processing Record 30 of Set 10 | tawkar
# City not found. Skipping...
# Processing Record 31 of Set 10 | oranjemund
# Processing Record 32 of Set 10 | kuna
# Processing Record 33 of Set 10 | dasoguz
# Processing Record 34 of Set 10 | luxor
# Processing Record 35 of Set 10 | sakaiminato
# Processing Record 36 of Set 10 | paamiut
# Processing Record 37 of Set 10 | acari
# Processing Record 38 of Set 10 | hun
# Processing Record 39 of Set 10 | okha
# Processing Record 40 of Set 10 | finschhafen
# Processing Record 41 of Set 10 | puerto quijarro
# Processing Record 42 of Set 10 | henin-beaumont
# Processing Record 43 of Set 10 | kosh-agach
# Processing Record 44 of Set 10 | novoagansk
# Processing Record 45 of Set 10 | payo
# Processing Record 46 of Set 10 | morales
# Processing Record 47 of Set 10 | los andes
# Processing Record 48 of Set 10 | tripoli
# Processing Record 49 of Set 10 | genhe
# Processing Record 50 of Set 10 | chara
# Processing Record 1 of Set 11 | wucheng
# Processing Record 2 of Set 11 | scarborough
# Processing Record 3 of Set 11 | biak
# Processing Record 4 of Set 11 | pacifica
# Processing Record 5 of Set 11 | bemidji
# Processing Record 6 of Set 11 | jalu
# Processing Record 7 of Set 11 | ust-nera
# Processing Record 8 of Set 11 | vila franca do campo
# Processing Record 9 of Set 11 | iwanai
# Processing Record 10 of Set 11 | taoudenni
# Processing Record 11 of Set 11 | tarbagatay
# Processing Record 12 of Set 11 | kruisfontein
# Processing Record 13 of Set 11 | tuatapere
# Processing Record 14 of Set 11 | bowen
# Processing Record 15 of Set 11 | yuncheng
# Processing Record 16 of Set 11 | duluth
# Processing Record 17 of Set 11 | tokur
# Processing Record 18 of Set 11 | dakar
# Processing Record 19 of Set 11 | asuncion nochixtlan
# Processing Record 20 of Set 11 | presque isle
# Processing Record 21 of Set 11 | campbell river
# Processing Record 22 of Set 11 | soria
# Processing Record 23 of Set 11 | bolkhov
# Processing Record 24 of Set 11 | coahuayana
# Processing Record 25 of Set 11 | harper
# Processing Record 26 of Set 11 | tabuk
# Processing Record 27 of Set 11 | kalabo
# Processing Record 28 of Set 11 | vestmanna
# Processing Record 29 of Set 11 | saint-joseph
# Processing Record 30 of Set 11 | damietta
# Processing Record 31 of Set 11 | mattru
# Processing Record 32 of Set 11 | butembo
# Processing Record 33 of Set 11 | santa fe
# Processing Record 34 of Set 11 | tocopilla
# Processing Record 35 of Set 11 | nchelenge
# Processing Record 36 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 37 of Set 11 | krasnoselkup
# Processing Record 38 of Set 11 | preobrazheniye
# Processing Record 39 of Set 11 | lufilufi
# Processing Record 40 of Set 11 | saint-pierre
# Processing Record 41 of Set 11 | safford
# Processing Record 42 of Set 11 | kaeng khlo
# City not found. Skipping...
# Processing Record 43 of Set 11 | hobyo
# Processing Record 44 of Set 11 | aklavik
# Processing Record 45 of Set 11 | saint george
# Processing Record 46 of Set 11 | kisangani
# Processing Record 47 of Set 11 | nieuw amsterdam
# Processing Record 48 of Set 11 | peleduy
# Processing Record 49 of Set 11 | banswara
# Processing Record 50 of Set 11 | hampton
# Processing Record 1 of Set 12 | cafelandia
# Processing Record 2 of Set 12 | ruwi
# Processing Record 3 of Set 12 | brigantine
# Processing Record 4 of Set 12 | norden
# Processing Record 5 of Set 12 | rajapalaiyam
# Processing Record 6 of Set 12 | hyeres
# Processing Record 7 of Set 12 | rio gallegos
# Processing Record 8 of Set 12 | marsh harbour
# Processing Record 9 of Set 12 | jamalpur
# Processing Record 10 of Set 12 | agadez
# Processing Record 11 of Set 12 | nushki
# Processing Record 12 of Set 12 | sur
# Processing Record 13 of Set 12 | gazanjyk
# Processing Record 14 of Set 12 | shakiso
# Processing Record 15 of Set 12 | cockburn town
# Processing Record 16 of Set 12 | neryungri
# Processing Record 17 of Set 12 | cuenca
# Processing Record 18 of Set 12 | wazzan
# City not found. Skipping...
# Processing Record 19 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 20 of Set 12 | ugoofaaru
# Processing Record 21 of Set 12 | atar
# Processing Record 22 of Set 12 | tevaitoa
# Processing Record 23 of Set 12 | coquimbo
# Processing Record 24 of Set 12 | nisia floresta
# Processing Record 25 of Set 12 | sitka
# Processing Record 26 of Set 12 | odessa
# Processing Record 27 of Set 12 | sahrak
# City not found. Skipping...
# Processing Record 28 of Set 12 | port-gentil
# Processing Record 29 of Set 12 | birin
# Processing Record 30 of Set 12 | port macquarie
# Processing Record 31 of Set 12 | brenes
# Processing Record 32 of Set 12 | aberdeen
# Processing Record 33 of Set 12 | ladario
# Processing Record 34 of Set 12 | el tigre
# Processing Record 35 of Set 12 | baruun-urt
# Processing Record 36 of Set 12 | xining
# Processing Record 37 of Set 12 | tres arroyos
# Processing Record 38 of Set 12 | wagar
# Processing Record 39 of Set 12 | lazaro cardenas
# Processing Record 40 of Set 12 | vrangel
# Processing Record 41 of Set 12 | acuna
# City not found. Skipping...
# Processing Record 42 of Set 12 | paragominas
# Processing Record 43 of Set 12 | gazojak
# Processing Record 44 of Set 12 | moree
# Processing Record 45 of Set 12 | teguldet
# Processing Record 46 of Set 12 | kochetok
# Processing Record 47 of Set 12 | ende
# Processing Record 48 of Set 12 | pouebo
# Processing Record 49 of Set 12 | acapulco
# Processing Record 50 of Set 12 | waipawa
# Processing Record 1 of Set 13 | vuktyl
# Processing Record 2 of Set 13 | udachnyy
# Processing Record 3 of Set 13 | hasaki
# Processing Record 4 of Set 13 | buncrana
# Processing Record 5 of Set 13 | port hardy
# Processing Record 6 of Set 13 | baherden
# Processing Record 7 of Set 13 | kirsanov
# Processing Record 8 of Set 13 | puri
# Processing Record 9 of Set 13 | mumias
# Processing Record 10 of Set 13 | sangmelima
# Processing Record 11 of Set 13 | phrai bung
# City not found. Skipping...
# Processing Record 12 of Set 13 | aksarka
# Processing Record 13 of Set 13 | manaure
# Processing Record 14 of Set 13 | seoul
# Processing Record 15 of Set 13 | nantucket
# Processing Record 16 of Set 13 | broken hill
# Processing Record 17 of Set 13 | lingao
# Processing Record 18 of Set 13 | prainha
# Processing Record 19 of Set 13 | lardos
# Processing Record 20 of Set 13 | sidi ali
# Processing Record 21 of Set 13 | vardo
# Processing Record 22 of Set 13 | the valley
# Processing Record 23 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 24 of Set 13 | burnie
# Processing Record 25 of Set 13 | andenes
# Processing Record 26 of Set 13 | vanimo
# Processing Record 27 of Set 13 | naze
# Processing Record 28 of Set 13 | qaqortoq
# Processing Record 29 of Set 13 | fort nelson
# Processing Record 30 of Set 13 | bonfim
# Processing Record 31 of Set 13 | mitu
# Processing Record 32 of Set 13 | mercedes
# Processing Record 33 of Set 13 | antipovka
# Processing Record 34 of Set 13 | huarmey
# Processing Record 35 of Set 13 | sambava
# Processing Record 36 of Set 13 | ornes
# Processing Record 37 of Set 13 | homer
# Processing Record 38 of Set 13 | tubmanburg
# Processing Record 39 of Set 13 | pochutla
# Processing Record 40 of Set 13 | acajutla
# Processing Record 41 of Set 13 | kuantan
# Processing Record 42 of Set 13 | guerrero negro
# Processing Record 43 of Set 13 | dunmore town
# Processing Record 44 of Set 13 | killybegs
# Processing Record 45 of Set 13 | illapel
# Processing Record 46 of Set 13 | tambul
# City not found. Skipping...
# Processing Record 47 of Set 13 | vieques
# Processing Record 48 of Set 13 | zambezi
# Processing Record 49 of Set 13 | falealupo
# City not found. Skipping...
# Processing Record 50 of Set 13 | dryden
# Processing Record 1 of Set 14 | chazuta
# Processing Record 2 of Set 14 | alyangula
# Processing Record 3 of Set 14 | pisco
# Processing Record 4 of Set 14 | mahebourg
# Processing Record 5 of Set 14 | tayu
# Processing Record 6 of Set 14 | muzhi
# Processing Record 7 of Set 14 | codrington
# Processing Record 8 of Set 14 | khudumelapye
# Processing Record 9 of Set 14 | semey
# Processing Record 10 of Set 14 | usinsk
# Processing Record 11 of Set 14 | kidal
# Processing Record 12 of Set 14 | san ramon
# Processing Record 13 of Set 14 | bubaque
# Processing Record 14 of Set 14 | ithaki
# Processing Record 15 of Set 14 | zhigansk
# Processing Record 16 of Set 14 | chumikan
# Processing Record 17 of Set 14 | obo
# Processing Record 18 of Set 14 | russell
# Processing Record 19 of Set 14 | atka
# City not found. Skipping...
# Processing Record 20 of Set 14 | villazon
# Processing Record 21 of Set 14 | shingu
# Processing Record 22 of Set 14 | axim
# Processing Record 23 of Set 14 | suao
# City not found. Skipping...
# Processing Record 24 of Set 14 | requena
# Processing Record 25 of Set 14 | olden
# Processing Record 26 of Set 14 | mahadday weyne
# City not found. Skipping...
# Processing Record 27 of Set 14 | pedernales
# Processing Record 28 of Set 14 | raga
# Processing Record 29 of Set 14 | crossfield
# Processing Record 30 of Set 14 | rehoboth
# Processing Record 31 of Set 14 | pandegelang
# Processing Record 32 of Set 14 | neuquen
# Processing Record 33 of Set 14 | whitehorse
# Processing Record 34 of Set 14 | cururupu
# Processing Record 35 of Set 14 | masasi
# Processing Record 36 of Set 14 | taga dzong
# City not found. Skipping...
# Processing Record 37 of Set 14 | lubyany
# Processing Record 38 of Set 14 | warmbad
# Processing Record 39 of Set 14 | polazna
# Processing Record 40 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 41 of Set 14 | teguise
# Processing Record 42 of Set 14 | chipinge
# Processing Record 43 of Set 14 | ambodifototra
# City not found. Skipping...
# Processing Record 44 of Set 14 | dalvik
# Processing Record 45 of Set 14 | kuytun
# Processing Record 46 of Set 14 | den helder
# Processing Record 47 of Set 14 | micheweni
# Processing Record 48 of Set 14 | kinshasa
# Processing Record 49 of Set 14 | lithakia
# Processing Record 50 of Set 14 | doha
# Processing Record 1 of Set 15 | manokwari
# Processing Record 2 of Set 15 | bonthe
# Processing Record 3 of Set 15 | gondanglegi
# Processing Record 4 of Set 15 | huancabamba
# Processing Record 5 of Set 15 | waverley
# Processing Record 6 of Set 15 | tzintzuntzan
# Processing Record 7 of Set 15 | sistranda
# Processing Record 8 of Set 15 | mersing
# Processing Record 9 of Set 15 | blagoyevo
# Processing Record 10 of Set 15 | mnogovershinnyy
# Processing Record 11 of Set 15 | port moresby
# Processing Record 12 of Set 15 | malangali
# Processing Record 13 of Set 15 | sakhipur
# Processing Record 14 of Set 15 | camana
# Processing Record 15 of Set 15 | pangkalanbuun
# Processing Record 16 of Set 15 | greymouth
# Processing Record 17 of Set 15 | champerico
# Processing Record 18 of Set 15 | pafos
# Processing Record 19 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 20 of Set 15 | manjacaze
# Processing Record 21 of Set 15 | disna
# Processing Record 22 of Set 15 | ghanzi
# Processing Record 23 of Set 15 | cascais
# Processing Record 24 of Set 15 | saldanha
# Processing Record 25 of Set 15 | nadym
# Processing Record 26 of Set 15 | matagami
# Processing Record 27 of Set 15 | zbarazh
# Processing Record 28 of Set 15 | zaigrayevo
# Processing Record 29 of Set 15 | okhotsk
# Processing Record 30 of Set 15 | pindiga
# Processing Record 31 of Set 15 | griffith
# Processing Record 32 of Set 15 | chimbote
# Processing Record 33 of Set 15 | westport
# Processing Record 34 of Set 15 | beyneu
# Processing Record 35 of Set 15 | petatlan
# Processing Record 36 of Set 15 | ketchikan
# Processing Record 37 of Set 15 | kindersley
# Processing Record 38 of Set 15 | babanusah
# City not found. Skipping...
# Processing Record 39 of Set 15 | lushunkou
# City not found. Skipping...
# Processing Record 40 of Set 15 | isla mujeres
# Processing Record 41 of Set 15 | amapa
# Processing Record 42 of Set 15 | chase
# Processing Record 43 of Set 15 | sao jose da coroa grande
# Processing Record 44 of Set 15 | baykit
# Processing Record 45 of Set 15 | njeru
# Processing Record 46 of Set 15 | taksimo
# Processing Record 47 of Set 15 | juneau
# Processing Record 48 of Set 15 | baoding
# Processing Record 49 of Set 15 | karasuk
# Processing Record 50 of Set 15 | liverpool
# Processing Record 1 of Set 16 | paradwip
# City not found. Skipping...
# Processing Record 2 of Set 16 | khasan
# Processing Record 3 of Set 16 | poronaysk
# Processing Record 4 of Set 16 | nguiu
# City not found. Skipping...
# Processing Record 5 of Set 16 | gamba
# Processing Record 6 of Set 16 | songjianghe
# Processing Record 7 of Set 16 | ayolas
# Processing Record 8 of Set 16 | tiarei
# Processing Record 9 of Set 16 | yagodnoye
# Processing Record 10 of Set 16 | valparaiso
# Processing Record 11 of Set 16 | taldan
# Processing Record 12 of Set 16 | kalangala
# Processing Record 13 of Set 16 | kitimat
# Processing Record 14 of Set 16 | chatrapur
# Processing Record 15 of Set 16 | abrau-dyurso
# Processing Record 16 of Set 16 | trincomalee
# Processing Record 17 of Set 16 | mardin
# Processing Record 18 of Set 16 | nicoya
# Processing Record 19 of Set 16 | guadalupe victoria
# Processing Record 20 of Set 16 | reforma
# Processing Record 21 of Set 16 | shanting
# Processing Record 22 of Set 16 | mount isa
# Processing Record 23 of Set 16 | viransehir
# Processing Record 24 of Set 16 | manthani
# Processing Record 25 of Set 16 | buqayq
# City not found. Skipping...
# Processing Record 26 of Set 16 | arman
# Processing Record 27 of Set 16 | praia da vitoria
# Processing Record 28 of Set 16 | kenai
# Processing Record 29 of Set 16 | bolungarvik
# City not found. Skipping...
# Processing Record 30 of Set 16 | indramayu
# Processing Record 31 of Set 16 | ulladulla
# Processing Record 32 of Set 16 | imbituba
# Processing Record 33 of Set 16 | valdivia
# Processing Record 34 of Set 16 | bayreuth
# Processing Record 35 of Set 16 | ofaqim
# Processing Record 36 of Set 16 | sao miguel do araguaia
# Processing Record 37 of Set 16 | caraz
# Processing Record 38 of Set 16 | kargasok
# Processing Record 39 of Set 16 | verkhnyaya khava
# Processing Record 40 of Set 16 | vavoua
# Processing Record 41 of Set 16 | komsomolskiy
# Processing Record 42 of Set 16 | willowmore
# Processing Record 43 of Set 16 | narsaq
# Processing Record 44 of Set 16 | isla vista
# Processing Record 45 of Set 16 | samusu
# City not found. Skipping...
# Processing Record 46 of Set 16 | swan hill
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 732

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Olafsvik      IS  64.8945  -23.7142     25.18        79          68
# 1            Bluff      NZ -46.6000  168.3333     59.92        78          25
# 2          Husavik      IS  66.0449  -17.3389     25.79        75         100
# 3  Bambous Virieux      MU -20.3428   57.7575     78.22        87         100
# 4            Tiksi      RU  71.6872  128.8694    -28.16       100         100
# 5           Albany      US  42.6001  -73.9662     42.06        78         100
# 6         Khatanga      RU  71.9667  102.5000    -29.69       100          43
# 7        Busselton      AU -33.6500  115.3333     59.07        72          15
# 8           Atuona      PF  -9.8000 -139.0333     77.85        79          30
# 9           Mehamn      NO  71.0357   27.8492     30.15        69         100
#
#    Wind Speed Current Description
# 0       14.38       broken clouds
# 1        3.89    scattered clouds
# 2       12.59          light snow
# 3       17.96       moderate rain
# 4        0.58     overcast clouds
# 5        3.00     overcast clouds
# 6        6.82    scattered clouds
# 7       14.76          few clouds
# 8       17.85          light rain
# 9        5.75     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# YOUR CODE HERE --- created this order in a previous cell

# Recreate the DataFrame by using the new column order
# YOUR CODE HERE

# Display sample data
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Olafsvik      IS  64.8945  -23.7142     25.18        79          68
# 1            Bluff      NZ -46.6000  168.3333     59.92        78          25
# 2          Husavik      IS  66.0449  -17.3389     25.79        75         100
# 3  Bambous Virieux      MU -20.3428   57.7575     78.22        87         100
# 4            Tiksi      RU  71.6872  128.8694    -28.16       100         100
# 5           Albany      US  42.6001  -73.9662     42.06        78         100
# 6         Khatanga      RU  71.9667  102.5000    -29.69       100          43
# 7        Busselton      AU -33.6500  115.3333     59.07        72          15
# 8           Atuona      PF  -9.8000 -139.0333     77.85        79          30
# 9           Mehamn      NO  71.0357   27.8492     30.15        69         100
#
#    Wind Speed Current Description
# 0       14.38       broken clouds
# 1        3.89    scattered clouds
# 2       12.59          light snow
# 3       17.96       moderate rain
# 4        0.58     overcast clouds
# 5        3.00     overcast clouds
# 6        6.82    scattered clouds
# 7       14.76          few clouds
# 8       17.85          light rain
# 9        5.75     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output = "WeatherPy_database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output)
